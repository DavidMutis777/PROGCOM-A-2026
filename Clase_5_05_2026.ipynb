# %% [markdown]
# <a href="https://colab.research.google.com/github/DavidMutis777/PROGCOM-A-2026/blob/main/Clase_5_05_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #PROGRAMACIÓN ORIENTADA A OBJETOS
# 1.Es un paradigma de programación, enfocado en construir objetos (no orientado al procedimiento)
# 2. Tienes 4 pilares fundamentales: Herencia, polimorfismo, abstracción, encapsulamientc
# 3. Ventajas
# • Modularidad: Manejar el código por trozos
# • Reusabilidad: Reusar clases y objetos
# • Mantenibilidad: Agregar fácilmente nuevos métodos.
# • Escalabilidad: Escalar a nuevas aplicaciones desde un mismo código . Seguridad: No todos pueden alterar el código
# 4. A los molde, croquis--> clase
# 5. Lo que produce una clase--> Instancia de clase-->Objeto
# 6. Funciones--> Método
# 7. Variables--> Atributos
# 8. Sintaxis
#
#
# ```
# class NombreClass(atributos):
# #Constructor
# def__init__(self,):
# pass
# def metodo1():
# pass
# def metodo 2():
# pass
#
# ```
# 9. Invocando una clase
#
#
# ```
# variable=
# ```

# %%
class disfraz():
#creando el contructor
  def __init__(self,color, talla, forma, material, personaje ):
    self.color=color
    self.talla=talla
    self.forma=forma
    self.material=material
    self.personaje=personaje

  def imprimir(self):
   return f"El disfraz es de {self.personaje}. Es talla {self.talla}."

# %%
class Edificio():
  #Construyendo el constructor
  def __init__(self,material, ubicación, fachada, ventanas, puertas):

    self.material=material
    self.ubicación=ubicación
    self.fachada=fachada
    self.ventanas=ventanas
    self.puertas=puertas

  def direccion(self,tipo):
    return f"Tipo de edificación:{tipo}\nDirección:{self.ubicación}"

  def descripcion(self, tipo):
    print(f" {self.nombre} es un{tipo} ubicado en {self.ubicación}")
    print(f" Tiene {self.ventanas} ventana(s), {self.puertas} puertas")
    print(f" Su fachada es {self.fachada} ")
